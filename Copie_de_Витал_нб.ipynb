# %% [markdown]
# <a href="https://colab.research.google.com/github/vitaleyeni5-pixel/vital/blob/main/Copie_de_%D0%92%D0%B8%D1%82%D0%B0%D0%BB_%D0%BD%D0%B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
project_title = "Mini Corpus"

# %%
print(project_title)
# Out:
# Mini Corpus
